# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
from cobra.io import read_sbml_model

# %%
read_sbml_model('iCW773_test7.xml')
# Out:
# No objective coefficients in model. Unclear what should be optimized
# <Model iCW773 at 0x24cd5836be0>

# %%
read_sbml_model('iCW773_psilocybin.xml')
# Out:
# No objective coefficients in model. Unclear what should be optimized
# <Model iCW773 at 0x24cd6f84d68>

# %%
# %%time
# !memote report snapshot iCW773_test7.xml --filename MemoteReportCorynebacterium.html
# Out:
# Scaling...Wall time: 7min 37s
# error: No objective coefficients in model. Unclear what should be optimized
# Writing snapshot report to 'MemoteReportCorynebacterium'.
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# ============================= test session starts =============================
# platform win32 -- Python 3.6.13, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: c:\users\s174916
# plugins: anyio-2.2.0
# collected 146 items / 1 skipped / 145 selected
#
# ..\..\..\..\..\..\.conda\envs\conda2_env\lib\site-packages\memote\suite\tests\test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..         [ 44%]
# ..\..\..\..\..\..\.conda\envs\conda2_env\lib\site-packages\memote\suite\tests\test_basic.py . [ 45%]
# .....FF.FF..FFF.F...FF                                                   [ 60%]
# ...

# %%
# %%time
# !memote report snapshot iCW773_psilocybin.xml --filename MemoteReportPsilocybin.html
# Out:
# Scaling...Wall time: 8min 46s
# error: No objective coefficients in model. Unclear what should be optimized
# Writing snapshot report to 'MemoteReportPsilocybin'.
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# ============================= test session starts =============================
# platform win32 -- Python 3.6.13, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: c:\users\s174916
# plugins: anyio-2.2.0
# collected 146 items / 1 skipped / 145 selected
#
# ..\..\..\..\..\..\.conda\envs\conda2_env\lib\site-packages\memote\suite\tests\test_annotation.py F [  0%]
# FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF..         [ 44%]
# ..\..\..\..\..\..\.conda\envs\conda2_env\lib\site-packages\memote\suite\tests\test_basic.py . [ 45%]
# .....F...F....F.....FF                                                   [ 60%]
# ...
