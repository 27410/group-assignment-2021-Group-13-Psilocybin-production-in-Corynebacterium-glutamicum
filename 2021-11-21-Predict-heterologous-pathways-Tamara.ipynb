# %% [markdown]
# ## Predict heterologous pathways

# %%
from IPython.display import display
import re
#importing the read_sbml_model function etc. from cobra
from cobra.io import read_sbml_model
from cameo import models
from cameo import load_model
from cameo.strain_design import pathway_prediction
#make sure model name is up to date!
model = read_sbml_model('iCW773_test7.xml') #assigning our model to the variable model
model.objective = model.reactions.CG_biomass_cgl_ATCC13032 # setting objective = biomass reaction as a start point. 

model
# Out:
# No objective coefficients in model. Unclear what should be optimized
# <Model iCW773 at 0x263432bec70>

# %%
solution = model.optimize()
solution
# Out:
# <Solution 0.429 at 0x26338d8f250>

# %%
## Testing alternative pathway for psilocybin production found here: https://github.com/biosustain/cameo-notebooks/blob/master/07-predict-heterologous-pathways.ipynb

# %%
predictor = pathway_prediction.PathwayPredictor(model)
pathways = predictor.run(product="psilocybin", max_predictions=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9980/2116035596.py in <module>
#       1 predictor = pathway_prediction.PathwayPredictor(model)
# ----> 2 pathways = predictor.run(product="psilocybin", max_predictions=1) #--> Psilocybin could not be found within the metabolites of the universal_model.
#
# ~\Anaconda3\lib\site-packages\cameo\strain_design\pathway_prediction\pathway_predictor.py in run(self, product, max_predictions, min_production, timeout, callback, silent, allow_native_exchanges)
#     284         """
#     285
# --> 286         product = self._find_product(product)
#     287
#     288         pathways = list()
#
# ~\Anaconda3\lib\site-packages\cameo\strain_design\pathway_prediction\pathway_predictor.py in _find_product(self, product)
#     455                 if metabolite.name == product:
#     456                     return metabolite
# --> 457             raise ValueError(
#     458                 "Specified product '{product}' could not be found. "
#     459                 "Try searching pathway_predictor_obj.universal_model.metabolites".format(product=product))
#
# ValueError: Specified product 'psilocybin' could not be found. Try searching pathway_predictor_obj.universal_model.metabolites

# %% [markdown]
# --> Psilocybin could not be found within the metabolites of the universal_model. Thus we will implement the pathway starting from L-tryptophan as published by Milne et al., 2020
